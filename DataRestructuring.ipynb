# %%
import pandas as pd
import uuid

# %%
sales = pd.read_csv('sales.csv')

# %%
sales.drop('promo_discount_2', axis=1, inplace=True)
sales.drop('promo_discount_type_2', axis=1, inplace=True)

# %%
sales
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 0             P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1             P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2             P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3             P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4             P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...             ...      ...         ...    ...      ...    ...    ...
# 19454833      P0748    S0125  2019-12-29    NaN      NaN    NaN  18.90
# 19454834      P0748    S0126  2019-12-29    NaN      NaN    NaN  18.90
# 19454835      P0748    S0131  2019-12-29    NaN      NaN    NaN  18.90
# 19454836      P0748    S0132  2019-12-29    NaN      NaN    NaN  18.90
# 19454837      P0748    S0142  2019-12-29    NaN      NaN    NaN  18.90
#
#          promo_type_1 promo_bin_1 promo_type_2 promo_bin_2
# ...

# %%
productDetails = pd.read_csv('product details.csv')

# %%
productHierarchy = pd.read_csv('product details.csv')

# %%
columns = ['product_id', 'product_length', 'product_depth', 'product_width', 'cluster_id']
productHierarchy.drop(columns, inplace=True, axis=1)

# %%
columns = ['hierarchy1_id', 'hierarchy2_id', 'hierarchy3_id', 'hierarchy4_id']
productDetails.drop(columns, inplace=True, axis=1)

# %%
productDetails
# Out:
#     product_id  product_length  product_depth  product_width cluster_id  \
# 0        P0000             5.0           20.0           12.0        NaN
# 1        P0001            13.5           22.0           20.0  cluster_5
# 2        P0002            22.0           40.0           22.0  cluster_0
# 3        P0004             2.0           13.0            4.0  cluster_3
# 4        P0005            16.0           30.0           16.0  cluster_9
# ..         ...             ...            ...            ...        ...
# 694      P0744             2.0            7.0            7.0        NaN
# 695      P0745             NaN            NaN            NaN  cluster_0
# 696      P0746             1.0            1.0            1.0  cluster_0
# 697      P0747            23.0           23.0           33.3  cluster_0
# 698      P0748             3.8            4.8           15.3  cluster_0
#
#     hierarchy5_id
# 0     H0004010534
# 1     H0105010006
# 2     H0315080028
# 3     H0314050003
# ...

# %%
sales
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 0             P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1             P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2             P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3             P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4             P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...             ...      ...         ...    ...      ...    ...    ...
# 19454833      P0748    S0125  2019-12-29    NaN      NaN    NaN  18.90
# 19454834      P0748    S0126  2019-12-29    NaN      NaN    NaN  18.90
# 19454835      P0748    S0131  2019-12-29    NaN      NaN    NaN  18.90
# 19454836      P0748    S0132  2019-12-29    NaN      NaN    NaN  18.90
# 19454837      P0748    S0142  2019-12-29    NaN      NaN    NaN  18.90
#
#          promo_type_1 promo_bin_1 promo_type_2 promo_bin_2
# ...

# %%
productHierarchy = productHierarchy.drop_duplicates(subset=['hierarchy5_id'], keep='first')

# %%
productHierarchy
# Out:
#     hierarchy1_id hierarchy2_id hierarchy3_id hierarchy4_id hierarchy5_id
# 0             H00         H0004       H000401     H00040105   H0004010534
# 1             H01         H0105       H010501     H01050100   H0105010006
# 2             H03         H0315       H031508     H03150800   H0315080028
# 3             H03         H0314       H031405     H03140500   H0314050003
# 4             H03         H0312       H031211     H03121109   H0312110917
# ..            ...           ...           ...           ...           ...
# 691           H03         H0313       H031305     H03130518   H0313051828
# 694           H03         H0311       H031108     H03110802   H0311080202
# 695           H02         H0209       H020908     H02090804   H0209080422
# 696           H03         H0314       H031407     H03140702   H0314070202
# 697           H01         H0107       H010701     H01070100   H0107010026
#
# [373 rows x 5 columns]

# %%
promotion = pd.read_csv('sales.csv')
# Out:
# C:\Users\0000000001\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
columns = ['product_id', 'store_id', 'date', 'sales', 'revenue', 'stock','price','promo_discount_2','promo_discount_type_2']
promotion.drop(columns, inplace=True, axis=1)

# %%
promotion = promotion.drop_duplicates(subset=['promo_type_1'], keep='first')

# %%
columns = ['promo_bin_1', 'promo_type_2','promo_bin_2']
sales.drop(columns, inplace=True, axis=1)

# %%
sales
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 0             P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1             P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2             P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3             P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4             P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...             ...      ...         ...    ...      ...    ...    ...
# 19454833      P0748    S0125  2019-12-29    NaN      NaN    NaN  18.90
# 19454834      P0748    S0126  2019-12-29    NaN      NaN    NaN  18.90
# 19454835      P0748    S0131  2019-12-29    NaN      NaN    NaN  18.90
# 19454836      P0748    S0132  2019-12-29    NaN      NaN    NaN  18.90
# 19454837      P0748    S0142  2019-12-29    NaN      NaN    NaN  18.90
#
#          promo_type_1
# 0                PR14
# 1                PR14
# 2                PR14
# ...

# %%
print(uuid.uuid1())
# Out:
# 9c03919b-b60e-11ec-aa33-b46bfc9136dc

# %%
sales['sales_id'] = (sales.product_id + sales.store_id + sales.date).map(hash)

# %%
sales
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 0             P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1             P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2             P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3             P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4             P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...             ...      ...         ...    ...      ...    ...    ...
# 19454833      P0748    S0125  2019-12-29    NaN      NaN    NaN  18.90
# 19454834      P0748    S0126  2019-12-29    NaN      NaN    NaN  18.90
# 19454835      P0748    S0131  2019-12-29    NaN      NaN    NaN  18.90
# 19454836      P0748    S0132  2019-12-29    NaN      NaN    NaN  18.90
# 19454837      P0748    S0142  2019-12-29    NaN      NaN    NaN  18.90
#
#          promo_type_1             sales_id
# 0                PR14  -330868926287599682
# ...

# %%
sales['sales_id'] = sales['sales_id'].abs()

# %%
len(sales['sales_id'].unique())
# Out:
# 19454838

# %%
sales
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 0             P0001    S0002  2017-01-02    0.0     0.00    8.0   6.25
# 1             P0001    S0012  2017-01-02    1.0     5.30    0.0   6.25
# 2             P0001    S0013  2017-01-02    2.0    10.59    0.0   6.25
# 3             P0001    S0023  2017-01-02    0.0     0.00    6.0   6.25
# 4             P0001    S0025  2017-01-02    0.0     0.00    1.0   6.25
# ...             ...      ...         ...    ...      ...    ...    ...
# 19454833      P0748    S0125  2019-12-29    NaN      NaN    NaN  18.90
# 19454834      P0748    S0126  2019-12-29    NaN      NaN    NaN  18.90
# 19454835      P0748    S0131  2019-12-29    NaN      NaN    NaN  18.90
# 19454836      P0748    S0132  2019-12-29    NaN      NaN    NaN  18.90
# 19454837      P0748    S0142  2019-12-29    NaN      NaN    NaN  18.90
#
#          promo_type_1             sales_id
# 0                PR14   330868926287599682
# ...

# %%
sales.to_csv("salesTable.csv", index=False)

# %%
storeDetails = pd.read_csv('store details.csv')

# %%
storeDetails.to_csv("storeDetailsTable.csv", index=False)

# %%
import pandas as pd

data = pd.read_csv('./Data Restructured/sales.csv')

# %%
salesDataSample = data.sample(n=50000)

# %%
salesDataSample
# Out:
#          product_id store_id        date  sales  revenue  stock  price  \
# 15854260      P0499    S0111  2019-07-05    3.0     2.78   10.0   0.75
# 10681310      P0398    S0026  2018-10-15    0.0     0.00   10.0  34.90
# 7154591       P0608    S0139  2018-04-15    0.0     0.00    6.0   9.90
# 6189337       P0015    S0125  2018-02-19    0.0     0.00   11.0   3.50
# 4750491       P0402    S0060  2017-11-23    0.0     0.00    4.0   7.75
# ...             ...      ...         ...    ...      ...    ...    ...
# 6428950       P0144    S0131  2018-03-05    0.0     0.00    5.0   4.95
# 5963942       P0453    S0069  2018-02-05    0.0     0.00    8.0   6.50
# 17528508      P0286    S0109  2019-09-25    0.0     0.00   14.0   1.45
# 14266264      P0466    S0110  2019-04-18    0.0     0.00    7.0  14.90
# 10504068      P0318    S0042  2018-10-06    0.0     0.00   25.0   1.00
#
#          promo_type_1             sales_id
# 15854260         PR14  2261064122461234591
# ...

# %%
salesDataSample.to_csv("salesDataSample.csv", index=False)
